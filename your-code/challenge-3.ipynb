# %% [markdown]
# # Challenge 3
#
# In this challenge we will work on the `Orders` data set. In your work you will apply the thinking process and workflow we showed you in Challenge 2.
#
# You are serving as a Business Intelligence Analyst at the headquarter of an international fashion goods chain store. Your boss today asked you to do two things for her:
#
# **First, identify two groups of customers from the data set.** The first group is **VIP Customers** whose **aggregated expenses** at your global chain stores are **above the 95th percentile** (aka. 0.95 quantile). The second group is **Preferred Customers** whose **aggregated expenses** are **between the 75th and 95th percentile**.
#
# **Second, identify which country has the most of your VIP customers, and which country has the most of your VIP+Preferred Customers combined.**

# %% [markdown]
# ## Q1: How to identify VIP & Preferred Customers?
#
# We start by importing all the required libraries:

# %%
# import required libraries
import numpy as np
import pandas as pd

# %% [markdown]
# Next, extract and import `Orders` dataset into a dataframe variable called `orders`. Print the head of `orders` to overview the data:

# %%
orders = pd.read_csv('Orders.csv')
orders
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0                0     536365    85123A  2010     12    3     8
# 1                1     536365     71053  2010     12    3     8
# 2                2     536365    84406B  2010     12    3     8
# 3                3     536365    84029G  2010     12    3     8
# 4                4     536365    84029E  2010     12    3     8
# ...            ...        ...       ...   ...    ...  ...   ...
# 397919      541904     581587     22613  2011     12    5    12
# 397920      541905     581587     22899  2011     12    5    12
# 397921      541906     581587     23254  2011     12    5    12
# 397922      541907     581587     23255  2011     12    5    12
# 397923      541908     581587     22138  2011     12    5    12
#
#                                 Description  Quantity          InvoiceDate  \
# 0        white hanging heart t-light holder         6  2010-12-01 08:26:00
# ...

# %% [markdown]
# ---
#
# "Identify VIP and Preferred Customers" is the non-technical goal of your boss. You need to translate that goal into technical languages that data analysts use:
#
# ## How to label customers whose aggregated `amount_spent` is in a given quantile range?

# %% [markdown]
# We break down the main problem into several sub problems:
#
# #### Sub Problem 1: How to aggregate the  `amount_spent` for unique customers?
#
# #### Sub Problem 2: How to select customers whose aggregated `amount_spent` is in a given quantile range?
#
# #### Sub Problem 3: How to label selected customers as "VIP" or "Preferred"?
#
# *Note: If you want to break down the main problem in a different way, please feel free to revise the sub problems above.*
#
# Now in the workspace below, tackle each of the sub problems using the iterative problem solving workflow. Insert cells as necessary to write your codes and explain your steps.

# %%
#Sub Problem 1: How to aggregate the amount_spent for unique customers?
agg = orders.groupby(['CustomerID']).agg({'amount_spent':sum})
agg
# Out:
#             amount_spent
# CustomerID
# 12346           77183.60
# 12347            4310.00
# 12348            1797.24
# 12349            1757.55
# 12350             334.40
# ...                  ...
# 18280             180.60
# 18281              80.82
# 18282             178.05
# 18283            2094.88
# 18287            1837.28
#
# [4339 rows x 1 columns]

# %%
# Sub Problem 2: How to select customers whose aggregated amount_spent is in a given quantile range?


# Calculate the quantiles of amount_spent
quantiles = agg['amount_spent'].quantile([0.75, 0.95])

# %%
quantiles
# Out:
# 0.75    1661.640
# 0.95    5840.182
# Name: amount_spent, dtype: float64

# %%
# Sub Problem 3: How to label selected customers as "VIP" or "Preferred"?
vip_customers = agg[agg['amount_spent'] > quantiles.loc[0.95]]
vip_customers
# Out:
#             amount_spent
# CustomerID
# 12346           77183.60
# 12357            6207.67
# 12359            6372.58
# 12409           11072.67
# 12415          124914.53
# ...                  ...
# 18109            8052.97
# 18139            8438.34
# 18172            7561.68
# 18223            6484.54
# 18229            7276.90
#
# [217 rows x 1 columns]

# %%
preferred_customers = agg[(agg['amount_spent'] > quantiles.loc[0.75]) & (agg['amount_spent'] <= quantiles.loc[0.95])]
preferred_customers
# Out:
#             amount_spent
# CustomerID
# 12347            4310.00
# 12348            1797.24
# 12349            1757.55
# 12352            2506.04
# 12356            2811.43
# ...                  ...
# 18259            2338.60
# 18260            2643.20
# 18272            3078.58
# 18283            2094.88
# 18287            1837.28
#
# [868 rows x 1 columns]

# %% [markdown]
# Now we'll leave it to you to solve Q2 & Q3, which you can leverage from your solution for Q1:
#
# ## Q2: How to identify which country has the most VIP Customers?

# %%
VIP_country = pd.merge(left = preferred_customers,
                       right = orders,
                       how = 'inner',
                       left_on = "CustomerID" ,
                       right_on = "CustomerID")
VIP_country
# Out:
#         CustomerID  amount_spent_x  Unnamed: 0  InvoiceNo StockCode  year  \
# 0            12347         4310.00       14938     537626     85116  2010
# 1            12347         4310.00       14939     537626     22375  2010
# 2            12347         4310.00       14940     537626     71477  2010
# 3            12347         4310.00       14941     537626     22492  2010
# 4            12347         4310.00       14942     537626     22771  2010
# ...            ...             ...         ...        ...       ...   ...
# 151776       18287         1837.28      392752     570715     22419  2011
# 151777       18287         1837.28      392753     570715     22866  2011
# 151778       18287         1837.28      423939     573167     23264  2011
# 151779       18287         1837.28      423940     573167     21824  2011
# 151780       18287         1837.28      423941     573167     21014  2011
#
#         month  day  hour                          Description  Quantity  \
# ...

# %%
VIP_country.groupby(['Country']).agg({'CustomerID':pd.Series.nunique}).reset_index()
# Out:
#             Country  CustomerID
# 0         Australia           2
# 1           Austria           3
# 2           Belgium          11
# 3            Canada           1
# 4   Channel Islands           3
# 5            Cyprus           3
# 6           Denmark           2
# 7              EIRE           1
# 8           Finland           4
# 9            France          20
# 10          Germany          29
# 11           Greece           1
# 12          Iceland           1
# 13           Israel           2
# 14            Italy           5
# 15            Japan           2
# 16          Lebanon           1
# 17            Malta           1
# 18           Norway           6
# 19           Poland           1
# 20         Portugal           5
# 21            Spain           7
# 22           Sweden           1
# 23      Switzerland           6
# 24   United Kingdom         755

# %%
# United Kingdom has the most VIP Customers

# %% [markdown]
# ## Q3: How to identify which country has the most VIP+Preferred Customers combined?

# %%
VIP_Preferred = pd.concat([vip_customers, preferred_customers])
VIP_Preferred
# Out:
#             amount_spent
# CustomerID
# 12346           77183.60
# 12357            6207.67
# 12359            6372.58
# 12409           11072.67
# 12415          124914.53
# ...                  ...
# 18259            2338.60
# 18260            2643.20
# 18272            3078.58
# 18283            2094.88
# 18287            1837.28
#
# [1085 rows x 1 columns]

# %%
VIP_Preferred_country = pd.merge(left = VIP_Preferred,
                       right = orders,
                       how = 'inner',
                       left_on = "CustomerID" ,
                       right_on = "CustomerID")
VIP_Preferred_country
# Out:
#         CustomerID  amount_spent_x  Unnamed: 0  InvoiceNo StockCode  year  \
# 0            12346        77183.60       61619     541431     23166  2011
# 1            12357         6207.67      444685     574740     22064  2011
# 2            12357         6207.67      444686     574740     21232  2011
# 3            12357         6207.67      444687     574740     22066  2011
# 4            12357         6207.67      444688     574740     22067  2011
# ...            ...             ...         ...        ...       ...   ...
# 256260       18287         1837.28      392752     570715     22419  2011
# 256261       18287         1837.28      392753     570715     22866  2011
# 256262       18287         1837.28      423939     573167     23264  2011
# 256263       18287         1837.28      423940     573167     21824  2011
# 256264       18287         1837.28      423941     573167     21014  2011
#
#         month  day  hour                          Description  Quantity  \
# ...

# %%
VIP_Preferred_country.groupby(['Country']).agg({'CustomerID':pd.Series.nunique}).reset_index()
# Out:
#             Country  CustomerID
# 0         Australia           4
# 1           Austria           3
# 2           Belgium          12
# 3            Canada           1
# 4   Channel Islands           4
# 5            Cyprus           4
# 6           Denmark           3
# 7              EIRE           3
# 8           Finland           5
# 9            France          29
# 10          Germany          39
# 11           Greece           1
# 12          Iceland           1
# 13           Israel           2
# 14            Italy           5
# 15            Japan           4
# 16          Lebanon           1
# 17            Malta           1
# 18      Netherlands           1
# 19           Norway           7
# 20           Poland           1
# 21         Portugal           7
# 22        Singapore           1
# 23            Spain           9
# 24           Sweden           2
# 25      Switzerland           9
# 26   United Kingdom         932

# %%
# United Kingdom also has the most VIP+Preferred Customers combined
